# %% [markdown]
# # Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# ## Overview
#
# In this Lab, you will learn how to integrate tools available in your organization with the Customer Support Agent using the Amazon Bedrock Gateway.
#
# The [Model Context Protocol (MCP)](https://modelcontextprotocol.io/docs/getting-started/intro) is an open protocol that standardizes how applications provide tools and context to Large Language Models (LLMs).
#
# With [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html), developers can convert APIs, Lambda functions, and existing services into MCP-compatible tools and make them available to agents through Gateway endpoints with just a few lines of code.
#
#
# **Workshop Journey:**
#
# - **Lab 1 (Done):** Create Agent Prototype - Built a functional customer support agent
# - **Lab 2 (Done):** Enhance with Memory - Added conversation context and personalization
# - **Lab 3 (Current):** Scale with Gateway & Identity - Shared tools across agents securely
# - **Lab 4:** Deploy to Production - Used AgentCore Runtime with observability
# - **Lab 5:** Evaluate Agent Performance - Monitor quality with online evaluations
# - **Lab 6:** Build User Interface - Create a customer-facing application
#
#
# ### Why AgentCore Gateway & Tool Sharing Matter
#
# Current State (Lab 1-2): Each agent has its own copy of tools. A practice that is not scalable and leads to:
#
# - Code duplication across different agents
# - Inconsistent tool behavior and maintenance overhead
# - No centralized security or access control
# - Difficulty scaling to multiple use cases
#
# After this lab, we will have centralized, reusable tools that can serve:
#
# - Customer Support Agent (our current use case)
# - Sales Agent (needs same product info and customer data)
# - Inventory Agent (needs same product info and warranty checking)
# - Returns Processing Agent (needs return policies and customer profiles)
#
# and other use cases.
#
# ### Adding secure authentication with AgentCore Identity
#
# Additionally, AgentCore Gateway requires you to securely authenticate both inbound and outbound connections. [AgentCore Identity](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/identity.html) provides seamless agent identity and access management across AWS services and third-party applications such as Slack and Zoom while supporting any standard identity providers such as Okta, Entra, and Amazon Cognito. In this lab we will see how AgentCore Gateway integrates with AgentCore Identity to provide secure connections via inbound and outbound authentication.
#
# For the inbound authentication, the AgentCore Gateway analyzes the OAuth token passed during invocation to decide allow or deny the access to a tool in the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
# During the inbound authorization flow, an agent or the MCP client calls an MCP tool in the AgentCore Gateway adding an OAuth access token (generated from the user’s IdP). AgentCore Gateway then validates the OAuth access token and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, OAuth will retrieve credentials of downstream resources using the resource credential provider for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.
#
#
# ## Architecture for Lab 3
#
# <div style="text-align:left">
#     <img src="images/architecture_lab3_gateway.png" width="75%"/>
# </div>
#
# *Web search tool is now centralized in AgentCore Gateway with secure identity-based access control. Multiple agents and use cases can share the same tool securely. We will also reuse the `check_warranty()` tool built for other applications and add the `web_search()` tool for use within other applications. `get_product_info()`, `get_return_policy()`, and `get_technical_support` remain as local tools as they are specific to the customer support use case*
#
# ### Key Features
# - **Seamlessly integrate AWS Lambda functions:** This example shows how to integrate your Agent with existing AWS Lambda functions to check the warranty of an item and to get the customer profile using Amazon Bedrock AgentCore Gateway.
# - **Secure your Gateway endpoint with Inbound Auth**: Only an Agent providing a valid JWT token can connect to the endpoint to use the tools
# - **Configure the Agent to use the MCP endpoint**: The Agent gets a valid JWT token and uses it to connect to the MCP endpoint provided by AgentCore Gateway
#
# ## Prerequisites
#
# * Python 3.12+
# * AWS credentials configured
# * Amazon Nova 2 Lite enabled on [Amazon Bedrock](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
# * Complete Lab 2 Add memory to the Customer Support Agent
# * These resources are created for you within an AWS workshop account
#     - AWS Lambda function
#     - AWS Lambda Execution IAM Role
#     - AgentCore Gateway IAM Role
#     - DynamoDB tables used by the AWS Lambda function.
#     - Cognito User Pool and User Pool Client

# %% [markdown]
# ## Step 1: Import required libraries

# %%
# Import libraries
import os
import sys
import boto3
import json

from strands import Agent
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
from mcp.client.streamable_http import streamablehttp_client
from lab_helpers.utils import (
    get_or_create_cognito_pool,
    put_ssm_parameter,
    get_ssm_parameter,
    load_api_spec,
)


sts_client = boto3.client("sts")
account_id = sts_client.get_caller_identity()['Account']
# Get AWS account details
REGION = boto3.session.Session().region_name

gateway_client = boto3.client(
    "bedrock-agentcore-control",
    region_name=REGION,
)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## Step 2: Give our agent a tool to access existing customer data
# AgentCore Gateway simplifies agent tool integration in three key ways:
#
# Universal MCP Support: Instantly make your tools compatible with any agent framework by exposing them through AgentCore Gateway's MCP standard
#
# Simple REST Integration: Transform existing REST services into agent tools by just adding them as AgentCore Gateway targets
#
# Lambda Flexibility: Expose Lambda functions as MCP endpoints that can call any API - demonstrated here with a function that checks warranty status
#
# AgentCore Gateway populates the Lambda context with the name of the tool to invoke, while the parameters passed to the tool are provided in the Lambda event:
#
# ```
# extended_tool_name = context.client_context.custom["bedrockAgentCoreToolName"]
# resource = extended_tool_name.split("___")[1]
# ```
#
# [Lambda function](./prerequisite/lambda/python/lambda_function.py)
#
# ```
# def lambda_handler(event, context):
#     if get_tool_name(event) == "check_warranty_status":
#         serial_number = get_named_parameter(event=event, name="serial_number")
#         customer_email = get_named_parameter(event=event, name="customer_email")
#
#         warranty_status = check_warranty_status(serial_number, customer_email)
#         return {"statusCode": 200, "body": warranty_status}
# ```

# %% [markdown]
# ## Step 3 Convert your web search tool to MCP
# Now that we are developing an MCP server using AgentCore Gateway, we can MCP-ify any tools which we think we'll use for multiple Agents. One of these tools might be a web search tool like we built in Lab1. As a result, we also converted the web search tool from Lab 1 into a Lambda tool within our AgentCore Gateway:
#
# [Web search Lambda](./prerequisite/lambda/python/web_search.py)
# ```
# from ddgs import DDGS
#
#
# def web_search(keywords: str, region: str = "us-en", max_results: int = 5) -> str:
#     """Search the web for updated information.
#
#     Args:
#         keywords (str): The search query keywords.
#         region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc.
#         max_results (int): The maximum number of results to return.
#
#     Returns:
#         List of dictionaries with search results.
#     """
#     try:
#         results = DDGS().text(keywords, region=region, max_results=max_results)
#         return results if results else "No results found."
#     except Exception as e:
#         return f"Search error: {str(e)}"
#
#
# print("✅ Web search tool ready")
# ```

# %% [markdown]
# ## Step 4 Create your function definition metadata
# Lastly, we need to write tool schema which describes the tools implemented by your Lambda function.
#
# This file has been already defined in [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json)
#
# ```
# [
#     {
#         "name": "check_warranty_status",
#         "description": "Check the warranty status of a product using its serial number and optionally verify via email",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "serial_number": {
#                     "type": "string"
#                 },
#                 "customer_email": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "serial_number"
#             ]
#         }
#     },
#     {
#         "name": "web_search",
#         "description": "Search the web for updated information using DuckDuckGo",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "keywords": {
#                     "type": "string",
#                     "description": "The search query keywords"
#                 },
#                 "region": {
#                     "type": "string",
#                     "description": "The search region (e.g., us-en, uk-en, ru-ru)"
#                 },
#                 "max_results": {
#                     "type": "integer",
#                     "description": "The maximum number of results to return"
#                 }
#             },
#             "required": [
#                 "keywords"
#             ]
#         }
#     }
# ]
# ```

# %% [markdown]
# ## Step 5. Create your AgentCore Gateway
#
# Now let's create the AgentCore Gateway to expose the Lambda function as MCP-compatible endpoint.
#
# To validate the callers authorized to invoke our tools we need to configure the Inbound Auth.
#
# Inbound Auth works using OAuth authorization, the standard for MCP servers. With OAuth the client application must authenticate with the OAuth authorizer before using the Gateway. Your client would receive an access token which is used at runtime.
#
# You need to specify an OAuth discovery server and client IDs. The Cloudformation provided with the workshop already provisioned the Cognito UserPool and UserPoolClient and it stored the discovery URL and the Client ID in dedicated SSM parameters.

# %%
gateway_name = "customersupport-gw"

cognito_config = get_or_create_cognito_pool(refresh_token=True)
auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [cognito_config["client_id"]],
        "discoveryUrl": cognito_config["discovery_url"],
    }
}

try:
    # create new gateway
    print(f"Creating gateway in region {REGION} with name: {gateway_name}")

    create_response = gateway_client.create_gateway(
        name=gateway_name,
        roleArn=get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role"),
        protocolType="MCP",
        authorizerType="CUSTOM_JWT",
        authorizerConfiguration=auth_config,
        description="Customer Support AgentCore Gateway",
    )

    gateway_id = create_response["gatewayId"]

    gateway = {
        "id": gateway_id,
        "name": gateway_name,
        "gateway_url": create_response["gatewayUrl"],
        "gateway_arn": create_response["gatewayArn"],
    }
    put_ssm_parameter("/app/customersupport/agentcore/gateway_id", gateway_id)
    put_ssm_parameter("/app/customersupport/agentcore/gateway_name", gateway_name)
    put_ssm_parameter(
        "/app/customersupport/agentcore/gateway_arn", create_response["gatewayArn"]
    )
    put_ssm_parameter(
        "/app/customersupport/agentcore/gateway_url", create_response["gatewayUrl"]
    )
    print(f"✅ Gateway created successfully with ID: {gateway_id}")

except Exception:
    # If gateway exists, collect existing gateway ID from SSM
    existing_gateway_id = get_ssm_parameter("/app/customersupport/agentcore/gateway_id")
    print(f"Found existing gateway with ID: {existing_gateway_id}")

    # Get existing gateway details
    gateway_response = gateway_client.get_gateway(gatewayIdentifier=existing_gateway_id)
    gateway = {
        "id": existing_gateway_id,
        "name": gateway_response["name"],
        "gateway_url": gateway_response["gatewayUrl"],
        "gateway_arn": gateway_response["gatewayArn"],
    }
    gateway_id = gateway["id"]
# Out:
# Creating gateway in region us-west-2 with name: customersupport-gw
# Found existing gateway with ID: customersupport-gw-owicuwpou2

# %% [markdown]
# ## Step 6. Add the Lambda function Target
# Now we will use the previously defined function definitions from [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json) to create a Lambda target within our Agent Gateway. This will define the tools that your gateway will host.
#
# Gateway allows you to attach multiple targets to a Gateway and you can change the targets / tools attached to a gateway at any point. Each target can have its own credential provider, but Gateway becomes a single MCP URL enabling access to all of the relevant tools for an agent across myriad APIs.

# %%
try:
    api_spec_file = "./prerequisite/lambda/api_spec.json"

    # Validate API spec file exists
    if not os.path.exists(api_spec_file):
        print(f"❌ API specification file not found: {api_spec_file}")
        sys.exit(1)

    api_spec = load_api_spec(api_spec_file)

    # Use Cognito for Inbound OAuth to our Gateway
    lambda_target_config = {
        "mcp": {
            "lambda": {
                "lambdaArn": get_ssm_parameter(
                    "/app/customersupport/agentcore/lambda_arn"
                ),
                "toolSchema": {"inlinePayload": api_spec},
            }
        }
    }

    # Create gateway target
    credential_config = [{"credentialProviderType": "GATEWAY_IAM_ROLE"}]

    create_target_response = gateway_client.create_gateway_target(
        gatewayIdentifier=gateway_id,
        name="LambdaUsingSDK",
        description="Lambda Target using SDK",
        targetConfiguration=lambda_target_config,
        credentialProviderConfigurations=credential_config,
    )

    print(f"✅ Gateway target created: {create_target_response['targetId']}")

except Exception as e:
    print(f"❌ Error creating gateway target: {str(e)}")
# Out:
# ❌ Error creating gateway target: An error occurred (ConflictException) when calling the CreateGatewayTarget operation: A target with name 'LambdaUsingSDK' already exists in this gateway

# %% [markdown]
# ## Step 7: Add our new MCP-based tools to our support agent
# Here we integrate our authentication token from Cognito into an MCPClient from Strands SDK to create an MCP Server object to integrate with our Strands Agent
# ### Step 7.1. Set up a secure MCP client object

# %%
print(f"Gateway Endpoint - MCP URL: {gateway['gateway_url']}")
# Set up MCP client
mcp_client = MCPClient(
    lambda: streamablehttp_client(
        gateway["gateway_url"],
        headers={"Authorization": f"Bearer {cognito_config['bearer_token']}"},
    )
)

with mcp_client:
    tools = mcp_client.list_tools_sync()
    print(f"   Found {len(tools)} tool(s):\n")
    for tool in tools:
        print(f"   ✅ {tool.mcp_tool.name}")
        print(f"      {tool.mcp_tool.description}\n")
# Out:
# Gateway Endpoint - MCP URL: https://customersupport-gw-owicuwpou2.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp
#    Found 2 tool(s):
#
#    ✅ LambdaUsingSDK___check_warranty_status
#       Check the warranty status of a product using its serial number and optionally verify via email
#
#    ✅ LambdaUsingSDK___web_search
#       Search the web for updated information using DuckDuckGo

# %% [markdown]
# ## Step 7.2. Access tools in our agent using our MCP client
# Now we will create our Strands Agent using the AgentCore Gateway we built along with the resources from previous labs. Our agent now uses a mix of local tools via our Strands Agent and MCP tools via AgentCore Gateway

# %%
from lab_helpers.lab1_strands_agent import (
    get_product_info,
    get_return_policy,
    get_technical_support,
    SYSTEM_PROMPT,
)

import uuid
from lab_helpers.lab2_memory import create_or_get_memory_resource
from bedrock_agentcore.memory.integrations.strands.config import AgentCoreMemoryConfig, RetrievalConfig
from bedrock_agentcore.memory.integrations.strands.session_manager import AgentCoreMemorySessionManager

memory_id = create_or_get_memory_resource()

SESSION_ID = str(uuid.uuid4())
CUSTOMER_ID = "customer_001"

memory_config = AgentCoreMemoryConfig(
        memory_id=memory_id,
        session_id=str(SESSION_ID),
        actor_id=CUSTOMER_ID,
        retrieval_config={
            "support/customer/{actorId}/semantic/": RetrievalConfig(top_k=3, relevance_score=0.2),
            "support/customer/{actorId}/preferences/": RetrievalConfig(top_k=3, relevance_score=0.2)
        }
    )

# Initialize the Bedrock model
model_id = "global.amazon.nova-2-lite-v1:0"
model = BedrockModel(
    model_id=model_id,
    temperature=0.3,  # Balanced between creativity and consistency
    region_name=REGION,
)


def create_agent(prompt):
    try:
        with mcp_client:
            tools = [
                get_product_info,
                get_return_policy,
                get_technical_support,
            ] + mcp_client.list_tools_sync()

            # Create the customer support agent
            agent = Agent(
                model=model,
                tools=tools,
                system_prompt=SYSTEM_PROMPT,
                session_manager=AgentCoreMemorySessionManager(memory_config, REGION),
            )
            response = agent(prompt)
            return response
    except Exception as e:
        raise e


print("✅ Customer support agent created successfully!")
# Out:
# ✅ Customer support agent created successfully!

# %% [markdown]
# ## Step 8: Test the agent with MCP tool access to existing APIs
#
# Let's test our agent with sample queries to ensure all features work correctly. You should see 5 tools in the output.

# %%
test_prompts = [
    # Warranty Checks
    "List all of your tools",
    "I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?",
    "I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.",
    "What are the warranty support guidelines?",
    "How can I fix Lenovo Thinkpad with a blue screen",
    "Tell me detailed information about the technical documentation on installing a new CPU",
]


# Function to test the agent
def test_agent_responses(prompts):
    for i, prompt in enumerate(prompts, 1):
        print(f"\nTest Case {i}: {prompt}")
        print("-" * 50)
        try:
            response = create_agent(prompt)
            print(response)
        except Exception as e:
            print(f"Error: {str(e)}")
        print("-" * 50)


# Run the tests
test_agent_responses(test_prompts)

print("\\n✅ Basic testing completed!")
# Out:
# Test Case 1: List all of your tools
# --------------------------------------------------
#
#
# I can help you with information about our tools! Here are all the tools available to me:
#
# ## Available Tools
#
# 1. **get_product_info** - Get detailed technical specifications and information for electronics products
#    - Parameters: product_type (required - e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# 2. **get_return_policy** - Get return policy information for a specific product category
#    - Parameters: product_category (required - e.g., 'smartphones', 'laptops', 'accessories')
#
# 3. **get_technical_support** - Provide technical support for specific issues
#    - Parameters: issue_description (required)
#
# 4. **LambdaUsingSDK___check_warranty_status** - Check the warranty status of a product using its serial number
#    - Parameters: serial_number (required), customer_email (optional)
#
# 5. **LambdaUsingSDK___web_search** - Search the web for updated information using DuckDuckGo
#    - Parameters: keywords (required), region (optional), max_results (optional)
#
# These tools allow me to help you with product specifications, return policies, technical support, warranty checks, and web research for updated information about electronics products.
#
# Based on your context, I can particularly help you with:
# - **Headphones**: For your competitive FPS gaming needs with low latency audio
# - **Laptops**: For your programming work requirements
# - **MacBook Pro support**: For your video editing work and overheating issues
# - **Warranty check**: For your MacBook Pro (order #MB-78432)
#
# Would you like me to help you with any specific product information or support using these tools?
#
# I can help you with information about our tools! Here are all the tools available to me:
#
# ## Available Tools
#
# 1. **get_product_info** - Get detailed technical specifications and information for electronics products
#    - Parameters: product_type (required - e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# 2. **get_return_policy** - Get return policy information for a specific product category
#    - Parameters: product_category (required - e.g., 'smartphones', 'laptops', 'accessories')
#
# 3. **get_technical_support** - Provide technical support for specific issues
#    - Parameters: issue_description (required)
#
# 4. **LambdaUsingSDK___check_warranty_status** - Check the warranty status of a product using its serial number
#    - Parameters: serial_number (required), customer_email (optional)
#
# 5. **LambdaUsingSDK___web_search** - Search the web for updated information using DuckDuckGo
#    - Parameters: keywords (required), region (optional), max_results (optional)
#
# These tools allow me to help you with product specifications, return policies, technical support, warranty checks, and web research for updated information about electronics products.
#
# Based on your context, I can particularly help you with:
# - **Headphones**: For your competitive FPS gaming needs with low latency audio
# - **Laptops**: For your programming work requirements
# - **MacBook Pro support**: For your video editing work and overheating issues
# - **Warranty check**: For your MacBook Pro (order #MB-78432)
#
# Would you like me to help you with any specific product information or support using these tools?
#
# --------------------------------------------------
#
# Test Case 2: I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?
# --------------------------------------------------
#
#
# I understand you're experiencing overheating issues with your iPhone 14. Let me help you with this. Overheating can be frustrating, especially with a new device. Let me provide you with some solutions and troubleshooting steps.
#
# ## Solutions for iPhone 14 Overheating Issues
#
# ### Immediate Troubleshooting Steps:
#
# 1. **Check for Software Updates**
#    - Go to Settings > General > Software Update
#    - Install any available iOS updates as they often include performance improvements
#
# 2. **Reduce Brightness**
#    - Lower your screen brightness or enable Auto-Brightness
#    - Settings > Display & Brightness
#
# 3. **Limit Background Activity**
#    - Go to Settings > General > Background App Refresh and turn it off for apps that don't need constant updates
#    - Disable unnecessary location services (Settings > Privacy & Security > Location Services)
#
# 4. **Manage Battery Usage**
#    - Check Settings > Battery to see which apps are using the most power
#    - Turn off features like Push Notifications, Automatic Downloads, and iCloud Sync for apps you don't use frequently
#
# 5. **Close Unused Apps**
#    - Double-press the home button (or slide over from the left on newer models) and swipe up to close apps running in the background
#
# ### Hardware and Settings Adjustments:
#
# **Enable Low Power Mode:**
# - When your battery drops to 20%, enable Low Power Mode (Settings > Battery)
# - This reduces background activity, email fetching, and visual effects
#
# **Limit Special Effects:**
# - Go to Settings > Accessibility > Motion and reduce or disable animations
#
# **Check for Overheating Triggers:**
# - Avoid using resource-intensive apps simultaneously (gaming, video editing, GPS navigation)
# - Keep your iPhone away from direct sunlight and hot surfaces
# - Don't place it under pillows or in tight clothing
#
# ### When to Contact Apple Support:
#
# You should contact Apple Support if:
# - The phone continues to overheat even after these steps
# - It gets hot during normal usage (not just during intensive tasks)
# - The overheating started immediately after purchase
#
# ## How to Get Support:
#
# 1. **Visit Apple Support Website**: support.apple.com
# 2. **Call Apple Support**: 1-800-275-2273 (US)
# 3. **Visit an Apple Store**: Schedule a Genius Bar appointment
#
# Would you like me to help you check your warranty status or connect you with Apple technical support for this issue? I can also provide more specific troubleshooting based on your exact usage patterns if you share more details about how you're using your iPhone when it overheats.
#
# ## Additional Considerations for Your MacBook Pro
#
# Since I see from your context that you're also using a MacBook Pro for video editing and experiencing overheating issues, would you like me to provide specific troubleshooting steps for your MacBook Pro as well? Your MacBook Pro is currently under warranty (order #MB-78432), so we can also check that warranty status if needed.
#
# Would you like:
# 1. Specific MacBook Pro overheating solutions?
# 2. Help checking your MacBook Pro warranty status?
# 3. Recommendations for cooling solutions for your video editing workflow?
#
# I understand you're experiencing overheating issues with your iPhone 14. Let me help you with this. Overheating can be frustrating, especially with a new device. Let me provide you with some solutions and troubleshooting steps.
#
# ## Solutions for iPhone 14 Overheating Issues
#
# ### Immediate Troubleshooting Steps:
#
# 1. **Check for Software Updates**
#    - Go to Settings > General > Software Update
#    - Install any available iOS updates as they often include performance improvements
#
# 2. **Reduce Brightness**
#    - Lower your screen brightness or enable Auto-Brightness
#    - Settings > Display & Brightness
#
# 3. **Limit Background Activity**
#    - Go to Settings > General > Background App Refresh and turn it off for apps that don't need constant updates
#    - Disable unnecessary location services (Settings > Privacy & Security > Location Services)
#
# 4. **Manage Battery Usage**
#    - Check Settings > Battery to see which apps are using the most power
#    - Turn off features like Push Notifications, Automatic Downloads, and iCloud Sync for apps you don't use frequently
#
# 5. **Close Unused Apps**
#    - Double-press the home button (or slide over from the left on newer models) and swipe up to close apps running in the background
#
# ### Hardware and Settings Adjustments:
#
# **Enable Low Power Mode:**
# - When your battery drops to 20%, enable Low Power Mode (Settings > Battery)
# - This reduces background activity, email fetching, and visual effects
#
# **Limit Special Effects:**
# - Go to Settings > Accessibility > Motion and reduce or disable animations
#
# **Check for Overheating Triggers:**
# - Avoid using resource-intensive apps simultaneously (gaming, video editing, GPS navigation)
# - Keep your iPhone away from direct sunlight and hot surfaces
# - Don't place it under pillows or in tight clothing
#
# ### When to Contact Apple Support:
#
# You should contact Apple Support if:
# - The phone continues to overheat even after these steps
# - It gets hot during normal usage (not just during intensive tasks)
# - The overheating started immediately after purchase
#
# ## How to Get Support:
#
# 1. **Visit Apple Support Website**: support.apple.com
# 2. **Call Apple Support**: 1-800-275-2273 (US)
# 3. **Visit an Apple Store**: Schedule a Genius Bar appointment
#
# Would you like me to help you check your warranty status or connect you with Apple technical support for this issue? I can also provide more specific troubleshooting based on your exact usage patterns if you share more details about how you're using your iPhone when it overheats.
#
# ## Additional Considerations for Your MacBook Pro
#
# Since I see from your context that you're also using a MacBook Pro for video editing and experiencing overheating issues, would you like me to provide specific troubleshooting steps for your MacBook Pro as well? Your MacBook Pro is currently under warranty (order #MB-78432), so we can also check that warranty status if needed.
#
# Would you like:
# 1. Specific MacBook Pro overheating solutions?
# 2. Help checking your MacBook Pro warranty status?
# 3. Recommendations for cooling solutions for your video editing workflow?
#
# --------------------------------------------------
#
# Test Case 3: I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.
# --------------------------------------------------
#
# --------------------------------------------------
#
# Test Case 4: What are the warranty support guidelines?
# --------------------------------------------------
#
#
# Thank you for your interest in warranty support guidelines. I understand you're looking for information about warranty policies for your devices.
#
# ## **Warranty Support Guidelines Overview**
#
# ### **General Warranty Principles**
#
# **1. Standard Warranty Coverage**
# - **Duration**: Typically 1 year from purchase date for most consumer electronics
# - **Coverage**: Manufacturing defects, hardware failures, and other issues not caused by user misuse
# - **Exclusions**: Damage from accidents, liquid exposure, unauthorized modifications, normal wear and tear
#
# **2. Extended Warranty Options**
# - **Extended Service Plans**: Available for purchase at time of sale or later through authorized retailers
# - **AppleCare+**: For Apple products, extends coverage up to 2 additional years beyond the standard warranty
# - **Accidental Damage Coverage**: Optional coverage for accidental drops, spills, and power surges
#
# **3. Warranty Activation Requirements**
# - **Proof of Purchase**: Required for all warranty claims (receipt, order confirmation, or packaging)
# - **Serial Number**: Must match the device being serviced
# - **Warranty Period**: Claims must be made within the active warranty timeframe
#
# ### **Common Warranty Scenarios**
#
# **🔧 Manufacturing Defects**
# - **Examples**: Faulty components, software bugs present from manufacture, hardware malfunctions
# - **Process**: Contact manufacturer support with proof of purchase and serial number
#
# **🔋 Battery Degradation**
# - **Policy**: Most warranties cover battery replacement if capacity drops below 80% of original after normal use
# - **Exclusion**: Normal battery wear from frequent full discharges or extreme temperatures
#
# **💻 Overheating Issues**
# - **Policy**: Covered if caused by manufacturing defect, not user-induced (e.g., blocked vents, malware)
# - **Process**: Diagnostic testing by authorized service center
#
# ### **How to Check Your Warranty Status**
#
# For your **Gaming Console Pro** device with serial number **MNO33333333**, I can check your warranty status right now if you'd like. Would you like me to verify your warranty coverage using your serial number?
#
# ### **Support Options**
#
# Depending on your device type, you may have access to:
# - **Manufacturer Support Portal**: Online troubleshooting, diagnostics, and repair requests
# - **Authorized Service Centers**: In-person repair services
# - **Phone Support**: Direct technical assistance
# - **Self-Service Options**: Software updates, driver downloads, and DIY fixes for non-hardware issues
#
# Would you like me to:
# 1. Check the warranty status for your Gaming Console Pro (serial: MNO33333333)?
# 2. Provide specific warranty information for your MacBook Pro (order #MB-78432)?
# 3. Explain the warranty process for your headphones purchase?
#
# Let me know which device you'd like to focus on, and I'll provide the exact warranty details and support options for you.
#
# Thank you for your interest in warranty support guidelines. I understand you're looking for information about warranty policies for your devices.
#
# ## **Warranty Support Guidelines Overview**
#
# ### **General Warranty Principles**
#
# **1. Standard Warranty Coverage**
# - **Duration**: Typically 1 year from purchase date for most consumer electronics
# - **Coverage**: Manufacturing defects, hardware failures, and other issues not caused by user misuse
# - **Exclusions**: Damage from accidents, liquid exposure, unauthorized modifications, normal wear and tear
#
# **2. Extended Warranty Options**
# - **Extended Service Plans**: Available for purchase at time of sale or later through authorized retailers
# - **AppleCare+**: For Apple products, extends coverage up to 2 additional years beyond the standard warranty
# - **Accidental Damage Coverage**: Optional coverage for accidental drops, spills, and power surges
#
# **3. Warranty Activation Requirements**
# - **Proof of Purchase**: Required for all warranty claims (receipt, order confirmation, or packaging)
# - **Serial Number**: Must match the device being serviced
# - **Warranty Period**: Claims must be made within the active warranty timeframe
#
# ### **Common Warranty Scenarios**
#
# **🔧 Manufacturing Defects**
# - **Examples**: Faulty components, software bugs present from manufacture, hardware malfunctions
# - **Process**: Contact manufacturer support with proof of purchase and serial number
#
# **🔋 Battery Degradation**
# - **Policy**: Most warranties cover battery replacement if capacity drops below 80% of original after normal use
# - **Exclusion**: Normal battery wear from frequent full discharges or extreme temperatures
#
# **💻 Overheating Issues**
# - **Policy**: Covered if caused by manufacturing defect, not user-induced (e.g., blocked vents, malware)
# - **Process**: Diagnostic testing by authorized service center
#
# ### **How to Check Your Warranty Status**
#
# For your **Gaming Console Pro** device with serial number **MNO33333333**, I can check your warranty status right now if you'd like. Would you like me to verify your warranty coverage using your serial number?
#
# ### **Support Options**
#
# Depending on your device type, you may have access to:
# - **Manufacturer Support Portal**: Online troubleshooting, diagnostics, and repair requests
# - **Authorized Service Centers**: In-person repair services
# - **Phone Support**: Direct technical assistance
# - **Self-Service Options**: Software updates, driver downloads, and DIY fixes for non-hardware issues
#
# Would you like me to:
# 1. Check the warranty status for your Gaming Console Pro (serial: MNO33333333)?
# 2. Provide specific warranty information for your MacBook Pro (order #MB-78432)?
# 3. Explain the warranty process for your headphones purchase?
#
# Let me know which device you'd like to focus on, and I'll provide the exact warranty details and support options for you.
#
# --------------------------------------------------
#
# Test Case 5: How can I fix Lenovo Thinkpad with a blue screen
# --------------------------------------------------
#
#
# ## **Lenovo ThinkPad Blue Screen Troubleshooting Guide**
#
# I understand you're experiencing a blue screen error on your Lenovo ThinkPad. Blue screens (also known as Blue Screen of Death or BSOD) can be caused by various issues ranging from software conflicts to hardware problems. Let me provide you with a comprehensive troubleshooting guide tailored for your Lenovo ThinkPad.
#
# ### 🔍 **Step-by-Step Troubleshooting Process**
#
# ---
#
# ### **1. Identify the Specific Blue Screen Error**
# The first step is to identify the exact error message you're seeing. Common BSOD error codes include:
# - **IRQL_NOT_LESS_OR_EQUAL**
# - **SYSTEM_THREAD_EXCEPTION_NOT_HANDLED**
# - **PAGE_FAULT_IN_NONPAGED_AREA**
# - **MEMORY_MANAGEMENT**
# - **CRITICAL_PROCESS_DIED**
#
# **How to capture the error:**
# - Take a photo of the screen or write down the exact error code
# - If possible, note any file names mentioned (e.g., `nvlddmkm.sys`, `ntoskrnl.exe`)
#
# ---
#
# ### **2. Basic Troubleshooting Steps**
#
# #### **A. Restart Your Computer**
# Sometimes a simple restart can resolve temporary issues. Hold down the power button for 10 seconds to force a shutdown, then restart normally.
#
# #### **B. Check for Recent Changes**
# Ask yourself:
# - Did you install new software or updates recently?
# - Did you make any hardware changes (RAM, hard drive, etc.)?
# - Did you download any suspicious files?
#
# #### **C. Scan for Malware**
# Malware can cause system instability. Run a full system scan using:
# - **Windows Defender** (built-in)
# - **Malwarebytes** (free version available)
#
# #### **D. Check Hardware Connections**
# - Ensure all cables are securely connected
# - If you recently added hardware, remove it and test
#
# ---
#
# ### **3. Advanced Troubleshooting**
#
# #### **A. Check Disk for Errors**
# 1. Open **Command Prompt as Administrator**
# 2. Run: `chkdsk C: /f /r`
# 3. Type `Y` to schedule the check on next restart
# 4. Restart your computer
#
# #### **B. Check Memory (RAM) for Errors**
# Use **Windows Memory Diagnostic**:
# 1. Search for "Windows Memory Diagnostic" in the Start menu
# 2. Choose "Restart now and check for problems"
#
# If errors are found, you may need to:
# - Reseat your RAM modules
# - Test each RAM stick individually
# - Replace faulty RAM
#
# #### **C. Update Drivers**
# Outdated or corrupted drivers are a common cause of BSODs:
# 1. **Update Windows**: Go to Settings > Update & Security > Windows Update
# 2. **Update Chipset Drivers**: Download the latest drivers from Lenovo's official website
# 3. **Update Graphics Drivers**: Especially important if the error mentions `nvlddmkm.sys` (NVIDIA) or `atikmpag.sys` (AMD)
#
# #### **D. Update BIOS**
# Outdated BIOS can cause compatibility issues:
# 1. Visit Lenovo's official support website
# 2. Enter your ThinkPad model number
# 3. Download and install the latest BIOS update **carefully**
#
# #### **E. Check Hard Drive Health**
# Use tools like:
# - **CrystalDiskInfo** (free)
# - **CHKDSK** (as mentioned above)
#
# If your hard drive is failing, back up your data immediately.
#
# #### **F. System Restore**
# If the issue started recently:
# 1. Type "Create a restore point" in the Search bar
# 2. Click "System Restore"
# 3. Choose a restore point from before the BSOD started
#
# #### **G. Clean Boot**
# This helps isolate software conflicts:
# 1. Press `Win + R`, type `msconfig`, press Enter
# 2. Go to the "Services" tab, check "Hide all Microsoft services"
# 3. Click "Disable all"
# 4. Go to the "Startup" tab, click "Open Task Manager"
# 5. Disable all startup items
# 6. Restart your computer
#
# If the system stabilizes in Clean Boot mode, re-enable items one by one to identify the culprit.
#
# ---
#
# ### **4. Hardware-Specific Troubleshooting for ThinkPad**
#
# #### **A. Check for Overheating**
# ThinkPad laptops can overheat, especially if vents are blocked:
# - Clean vents and fans using compressed air
# - Use a cooling pad if working in a hot environment
#
# #### **B. Check Battery and Power Settings**
# - Reset the CMOS battery:
# 1. Shut down and unplug your ThinkPad
#   2. Remove the battery (if removable)
#   3. Wait30 seconds, reinsert battery
#   4. Reconnect power and start
#
# #### **C. Lenovo-Specific Tools**
# - **Lenovo Vantage**: Provides system diagnostics and updates
# - **Lenovo Solution Center**: Runs comprehensive hardware tests
#
# ---
#
# ### **5. When to Seek Professional Help**
#
# Contact Lenovo Support or visit an authorized serviceError: Agent has reached an unrecoverable state due to max_tokens limit. For more information see: https://strandsagents.com/latest/user-guide/concepts/agents/agent-loop/#maxtokensreachedexception
# --------------------------------------------------
#
# Test Case 6: Tell me detailed information about the technical documentation on installing a new CPU
# --------------------------------------------------
# **
#
# ## **Comprehensive Technical Documentation: Installing a New CPU**
#
# ### **1. Introduction**
# Installing a new Central Processing Unit (CPU) is a critical upgrade that can significantly enhance your computer's performance. This guide provides a detailed, step-by-step approach to CPU installation, covering everything from preparation to post-installation verification. Whether you're a novice or an experienced builder, this documentation ensures a smooth and successful process.
#
# ---
#
# ## **2. Pre-Installation Preparation**
#
# ### **2.1. Research and Compatibility Check**
# Before purchasing and installing a new CPU, thorough research is essential to ensure compatibility and avoid potential issues.
#
# **Key Compatibility Factors:**
# - **Motherboard Socket Type**: Identify your motherboard's socket (e.g., AM5, LGA 1700, SP3). This determines which CPUs are compatible.
# - **Chipset Compatibility**: Verify that your motherboard's chipset supports the new CPU. Some older chipsets may require a BIOS update.
# - **BIOS Version**: Older motherboards may need a BIOS update to recognize newer CPUs. Check your motherboard manufacturer's support page for compatible BIOS versions.
# - **Thermal Solution**: Ensure you have an appropriate CPU cooler for the new processor. Stock coolers are usually included with CPUs, but high-performance CPUs may require aftermarket cooling solutions.
#
# **Steps to Verify Compatibility:**
# 1. **Check Motherboard Manual**: Review the motherboard manual for supported CPU lists and socket specifications.
# 2. **Visit Manufacturer Websites**: Access the motherboard and CPU manufacturer websites for updated compatibility information.
# 3. **Consult Online Databases**: Use resources like HWBot.org or hardware bot databases to cross-reference compatibility.
#
# ### **2.2. Gather Necessary Tools and Materials**
# Having the right tools and materials is crucial for a successful CPU installation.
#
# **Essential Tools:**
# - **Screwdrivers**: A Phillips-head screwdriver (typically provided with the motherboard) for securing the CPU cooler.
# - **Anti-Static Wrist Strap**: To prevent electrostatic discharge (ESD) damage to sensitive components.
# - **CPU Cooler**: Ensure you have an appropriate cooler for the new CPU. Stock coolers are generally sufficient for most users, but high-performance CPUs may require liquid nitrogen cooling or high-end air coolers.
# - **Compression Socks or Zip Ties**: For managing cables and ensuring proper airflow.
# - **Thermal Paste**: If the CPU does not come with pre-applied thermal paste, you'll need high-quality thermal paste (e.g., Arctic MX-6, Noctua NT-H1).
# - **Isopropyl Alcohol and Lint-Free Cloth**: For cleaning the CPU and cooler base before applying thermal paste.
#
# **Optional Tools:**
# - **CPU Sag Bracket**: Useful for heavy coolers to prevent sag, especially in smaller cases.
# - **Magnifying Glass**: To inspect CPU gold contacts and socket pins for damage.
# - **Flashlight**: To better see the CPU alignment and socket details.
#
# ### **2.3. Safety Precautions**
# Safety is paramount when working with computer hardware to prevent damage to components and ensure personal safety.
#
# **Key Safety Measures:**
# - **Power Down and Unplug**: Ensure your computer is powered off and unplugged from the power supply before beginning any hardware modifications.
# - **Ground Yourself**: Use an anti-static wrist strap connected to a grounded metal object to prevent electrostatic discharge (ESD). If you don't have a wrist strap, frequently touch a grounded metal object (like the computer case) to discharge static electricity.
# - **Work in a Clean Environment**: Work on an anti-static mat or a clean, static-free surface to minimize the risk of ESD and dust accumulation.
# - **Avoid Working on Carpet**: Carpet can generate static electricity. Work on a wooden or concrete floor if possible.
# - **Handle Components by Edges**: When handling the CPU, hold it by the edges to avoid touching the gold contacts, which can be damaged by oils and moisture from your fingers.
#
# ---
#
# ## **3. Removing the Old CPU**
#
# ### **3.1. Open the Case**
# Before accessing the motherboard, you need to open your computer case.
#
# **Steps:**
# 1. **Unplug Power Connectors**: Disconnect the power supply and all peripheral connections (hard drive, optical drive, etc.) to prevent accidental deployment of power.
# 2. **Remove Side Panel**: Unscrew and remove the side panel of your computer case to access the motherboard. The method varies depending on your case design.
# 3. **Disconnect Cables**: Detach any cables connected to the motherboard (e.g., power button, reset button, front panel USB) to provide ample space to work.
#
# ### **3.2. Unlock the CPU Socket**
# Most modern motherboards have a lever or latch system to unlock the CPU socket. The exact mechanism varies by socket type.
#
# **Common Socket Unlocking Methods:**
# - **LGA Sockets (e.g., LGA 1700)**: Locate the gold triangle on the socket and the corresponding gold triangle on the CPU. Use the socket lever to unlock the socket by lifting it.
# - **AM Sockets (e.g., AM5)**: Similar toError: Agent has reached an unrecoverable state due to max_tokens limit. For more information see: https://strandsagents.com/latest/user-guide/concepts/agents/agent-loop/#maxtokensreachedexception
# --------------------------------------------------
# \n✅ Basic testing completed!

# %% [markdown]
# ## [Optional Section] AgentCore Policy

# %% [markdown]
# ### Step 9: Create Policy Engine
#
# Create a Policy Engine to contain Cedar authorization policies for fine-grained access control.

# %%
# Try to import from toolkit, fall back to custom implementation if not available
try:
    from bedrock_agentcore_starter_toolkit.operations.policy.client import PolicyClient
    print("✅ Using toolkit PolicyClient")
except ImportError:
    from utils.policy_utils import PolicyClient
    print("✅ Using custom PolicyClient (toolkit policy module not available)")

# Initialize the policy client
policy_client = PolicyClient(region_name=REGION)

print("\n🔧 Creating Policy Engine...")

# Create or get existing policy engine
# The policy engine is a container for all our authorization policies
engine = policy_client.create_or_get_policy_engine(
    name="customersupport_pe",
    description="Policy engine for customer support gateway",
)

engine_id = engine['policyEngineId']
engine_arn = engine['policyEngineArn']
put_ssm_parameter("/app/customersupport/agentcore/policy_engine_id", engine_id)

print(f"\n✅ Policy Engine ready")
print(f"   Engine ID: {engine_id}")
print(f"   Engine ARN: {engine_arn}")
# Out:
# 2026-03-03 14:08:50,356 - bedrock_agentcore.policy - INFO - Creating or getting Policy Engine: customersupport_pe
# 2026-03-03 14:08:50,469 - bedrock_agentcore.policy - INFO - ✓ Found existing Policy Engine: customersupport_pe
# ✅ Using toolkit PolicyClient
#
# 🔧 Creating Policy Engine...
#
# ✅ Policy Engine ready
#    Engine ID: customersupport_pe-i7pukqsewa
#    Engine ARN: arn:aws:bedrock-agentcore:us-west-2:061264750636:policy-engine/customersupport_pe-i7pukqsewa

# %% [markdown]
# ### [Optional]:  Create Cedar Policy using Natural Language
#
# AgentCore Policy provides the ability to generate Cedar policies using natural language to enforce scope-based access.

# %%
import time
# Create Cedar policy for approve tool (write scope)
print("\n📝 Generating Cedar Policy from Natural language...")

nl_input = "Allow tag username == 'testuser' to perform check warranty status on the customer support gateway."

warranty_tool_policy = policy_client.generate_policy(
    policy_engine_id=engine["policyEngineId"],
    name=f"nl_policy_{int(time.time())}",
    resource={"arn": gateway["gateway_arn"]},
    content={"rawText": nl_input},
    fetch_assets=True,
)

print("✅ Policy generated from natural language")
# Out:
# 2026-03-03 14:11:39,534 - bedrock_agentcore.policy - INFO - Generating policies from natural language: nl_policy_1772547099
# 2026-03-03 14:11:39,535 - bedrock_agentcore.policy - INFO - Starting Policy Generation: nl_policy_1772547099
# 📝 Generating Cedar Policy from Natural language...
# 2026-03-03 14:11:39,858 - bedrock_agentcore.policy - INFO - ✓ Policy Generation initiated: arn:aws:bedrock-agentcore:us-west-2:061264750636:policy-engine/customersupport_pe-i7pukqsewa/policy-generation/nl_policy_1772547099-l6avjfzg37
# 2026-03-03 14:11:39,858 - bedrock_agentcore.policy - INFO - Started generation nl_policy_1772547099-l6avjfzg37, waiting for completion...
# 2026-03-03 14:11:39,952 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 1/30)...
# 2026-03-03 14:11:42,051 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 2/30)...
# 2026-03-03 14:11:44,140 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 3/30)...
# 2026-03-03 14:11:46,203 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 4/30)...
# 2026-03-03 14:11:48,284 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 5/30)...
# 2026-03-03 14:11:50,352 - bedrock_agentcore.policy - INFO - Generation in progress (attempt 6/30)...
# 2026-03-03 14:11:52,424 - bedrock_agentcore.policy - INFO - ✓ Policy generation complete
# 2026-03-03 14:11:54,425 - bedrock_agentcore.policy - INFO - Fetching generated policy assets...
# 2026-03-03 14:11:54,516 - bedrock_agentcore.policy - INFO - ✓ Fetched 1 generated policies
# ✅ Policy generated from natural language

# %%
print("📋 Generated Cedar Policies:\n")
print("=" * 80)

# Allow warranty status policy
print("\n1️⃣  Warranty Status")
print("-" * 80)
warranty_tool_policy_cedar = warranty_tool_policy["generatedPolicies"][0]["definition"]["cedar"]["statement"]
print(warranty_tool_policy_cedar)

print("\n" + "=" * 80)
# Out:
# 📋 Generated Cedar Policies:
#
# ================================================================================
#
# 1️⃣  Warranty Status
# --------------------------------------------------------------------------------
# permit(
#   principal,
#   action == AgentCore::Action::"LambdaUsingSDK___check_warranty_status",
#   resource == AgentCore::Gateway::"arn:aws:bedrock-agentcore:us-west-2:061264750636:gateway/customersupport-gw-owicuwpou2"
# ) when {
#   (principal.hasTag("username")) && ((principal.getTag("username")) == "testuser")
# };
#
# ================================================================================

# %% [markdown]
# ### Step 10 : Create Cedar Policy
#
# Let's generate Cedar policies to enforce scope-based access. We can write scope for approve operations, read scope for create/list operations.
#
# For the scope of this workshop, we will use pre-crafted allow/deny cedar policies to ensure consistency for all users.

# %%
# Providing policies to allow for consistency in use case execution
allow_policy = {
    "cedar": {
        "statement": f"""permit(
            principal,
            action in [AgentCore::Action::"LambdaUsingSDK___check_warranty_status", AgentCore::Action::"LambdaUsingSDK___web_search"],
            resource == AgentCore::Gateway::"arn:aws:bedrock-agentcore:{REGION}:{account_id}:gateway/{gateway['id']}"
        ) when {{
            (principal.hasTag("username")) && 
            ((principal.getTag("username")) == "testuser")
        }};"""
    }
}

# deny web search for "iPhone 8" keywords
deny_web_search_policy = {
    "cedar": {
        "statement": f"""forbid(
            principal,
            action == AgentCore::Action::"LambdaUsingSDK___web_search",
            resource == AgentCore::Gateway::"arn:aws:bedrock-agentcore:{REGION}:{account_id}:gateway/{gateway['id']}"
        ) when {{
            context.input has keywords &&
            context.input.keywords like "*iPhone 8*"
        }};"""
    }
}

# %% [markdown]
# ### Step 11: Add Policies in Policy Engine
#
# Create the generated Cedar policies in the Policy Engine.

# %%
print("🔧 Creating policies in Policy Engine...\n")

# Create allow both tools policy
warranty_result = policy_client.create_or_get_policy(
    policy_engine_id=engine["policyEngineId"],
    name="allow_policy",
    description="Allow web_search and check_warranty_status calls",
    definition=allow_policy
)
print("✅ Policy ready: allow_policy")
print("   Tools allowed: check_warranty_status and web_search\n")

# Create deny web search list policy
web_search_deny_result = policy_client.create_or_get_policy(
    policy_engine_id=engine["policyEngineId"],
    name="deny_web_search",
    description="Deny web_search tool call for iPhone 8",
    definition=deny_web_search_policy
)
print("✅ Policy ready: deny_web_search")
print("   Tools denied conditionally: web_search\n")

print("✅ All policies ready!")
# Out:
# 2026-03-03 14:12:26,661 - bedrock_agentcore.policy - INFO - Creating or getting Policy: allow_policy
# 2026-03-03 14:12:26,762 - bedrock_agentcore.policy - INFO - ✓ Found existing Policy: allow_policy
# 2026-03-03 14:12:26,763 - bedrock_agentcore.policy - INFO - Creating or getting Policy: deny_web_search
# 2026-03-03 14:12:26,860 - bedrock_agentcore.policy - INFO - ✓ Found existing Policy: deny_web_search
# 🔧 Creating policies in Policy Engine...
#
# ✅ Policy ready: allow_policy
#    Tools allowed: check_warranty_status and web_search
#
# ✅ Policy ready: deny_web_search
#    Tools denied conditionally: web_search
#
# ✅ All policies ready!

# %% [markdown]
# ### Step 12: Update Gateway IAM Role Permissions
#
# Before attaching the Policy Engine, we need to grant the Gateway IAM role permission to access the Policy Engine.

# %%
role_arn = get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role")
role_name = role_arn.split('/')[-1] 

iam_client = boto3.client('iam')
print("🔧 Updating Gateway IAM role with Policy Engine permissions...")

# Policy document that grants access to Policy Engine
policy_document = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": [
                "bedrock-agentcore:*"
            ],
            "Resource": [
                f"arn:aws:bedrock-agentcore:{REGION}:{account_id}:policy-engine/*",
                f"arn:aws:bedrock-agentcore:{REGION}:{account_id}:gateway/*"
            ]
        }
    ]
}

try:
    # Add inline policy to the role
    iam_client.put_role_policy(
        RoleName=role_name,
        PolicyName="PolicyEngineAccess",
        PolicyDocument=json.dumps(policy_document)
    )
    
    print(f"✅ IAM role updated successfully")
    print(f"   Role: {role_name}")
    print(f"   Added permissions: GetPolicyEngine, GetPolicy, ListPolicies")
    print("\n⏳ Waiting 10 seconds for IAM changes to propagate...")
    time.sleep(10)
    
    print("✅ Ready to attach Policy Engine")
    
except Exception as e:
    print(f"❌ Error updating IAM role: {e}")
    print("\nYou may need to manually add these permissions to the role.")
# Out:
# 🔧 Updating Gateway IAM role with Policy Engine permissions...
# ✅ IAM role updated successfully
#    Role: workshop-studio-GatewayAgentCoreRole-5Z5ARzXYuusp
#    Added permissions: GetPolicyEngine, GetPolicy, ListPolicies
#
# ⏳ Waiting 10 seconds for IAM changes to propagate...
# ✅ Ready to attach Policy Engine

# %% [markdown]
# ### Step 13: Attach Policy Engine to Gateway
#
# Enable policy enforcement by attaching the Policy Engine to the Gateway in ENFORCE mode.

# %%
from bedrock_agentcore_starter_toolkit.operations.gateway.client import GatewayClient

# Initialize gateway client
gateway_client_toolkit = GatewayClient(region_name=REGION)

print("🔧 Attaching Policy Engine to Gateway...")
print(f"   Mode: ENFORCE (policies will block unauthorized requests)\n")

# Attach the policy engine to the gateway
update_response = gateway_client_toolkit.update_gateway_policy_engine(
    gateway_identifier=gateway["id"],
    policy_engine_arn=engine["policyEngineArn"],
    mode="ENFORCE"
)

print("✅ Policy Engine attached successfully!")
print(f"   Gateway ID: {gateway['id']}")
print(f"   Policy Engine: {engine['policyEngineId']}")
print(f"   Mode: ENFORCE")
print("\n🔒 Authorization is now active!")
# Out:
# 2026-03-03 14:12:41,826 - bedrock_agentcore.gateway - INFO - Attaching policy engine to gateway
# 2026-03-03 14:12:41,826 - bedrock_agentcore.gateway - INFO - Updating gateway customersupport-gw-owicuwpou2
# 2026-03-03 14:12:41,941 - bedrock_agentcore.gateway - INFO -   Policy Engine ARN: arn:aws:bedrock-agentcore:us-west-2:061264750636:policy-engine/customersupport_pe-i7pukqsewa
# 2026-03-03 14:12:41,942 - bedrock_agentcore.gateway - INFO -   Mode: ENFORCE
# 🔧 Attaching Policy Engine to Gateway...
#    Mode: ENFORCE (policies will block unauthorized requests)
# 2026-03-03 14:12:42,231 - bedrock_agentcore.gateway - INFO - ✓ Gateway update initiated
# 2026-03-03 14:12:42,231 - bedrock_agentcore.gateway - INFO -   Waiting for gateway to be ready...
# 2026-03-03 14:12:44,414 - bedrock_agentcore.gateway - INFO - ✓ Gateway update complete
# ✅ Policy Engine attached successfully!
#    Gateway ID: customersupport-gw-owicuwpou2
#    Policy Engine: customersupport_pe-i7pukqsewa
#    Mode: ENFORCE
#
# 🔒 Authorization is now active!

# %% [markdown]
# ### Step 14: Test Policy Enforcement

# %%
test_prompts = [
    "List all of your tools",
    "Search the web for heating issues with Samsung zfold 7",
    "Search the internet for heating issues with iPhone 8"
]

# Function to test the agent
def test_agent_responses(prompts):
    for i, prompt in enumerate(prompts, 1):
        print(f"\nTest Case {i}: {prompt}")
        print("-" * 50)
        try:
            response = create_agent(prompt)
            print(response)
        except Exception as e:
            print(f"Error: {str(e)}")
        print("-" * 50)

# Run the tests
test_agent_responses(test_prompts)

print("\\n✅ Policy testing completed!")
# Out:
# Test Case 1: List all of your tools
# --------------------------------------------------
#
#
# I see the user is asking me to list all of my tools again. Let me provide a comprehensive list of all available tools with descriptions and parameters.
#
# ## Available Tools
#
# Here are all the tools I have access to:
#
# ### 1. **get_product_info**
# **Description**: Get detailed technical specifications and information for electronics products.
#
# **Parameters**:
# - `product_type` (required): Electronics product type (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# ### 2. **get_return_policy**
# **Description**: Get return policy information for a specific product category.
#
# **Parameters**:
# - `product_category` (required): Electronics category (e.g., 'smartphones', 'laptops', 'accessories')
#
# ### 3. **get_technical_support**
# **Description**: Provide technical support for specific issues
#
# **Parameters**:
# - `issue_description` (required): Description of the technical issue
#
# ### 4. **LambdaUsingSDK___check_warranty_status**
# **Description**: Check the warranty status of a product using its serial number and optionally verify via email
#
# **Parameters**:
# - `serial_number` (required): Property serial_number
# - `customer_email` (optional): Property customer_email
#
# ### 5. **LambdaUsingSDK___web_search**
# **Description**: Search the web for updated information using DuckDuckGo
#
# **Parameters**:
# - `keywords` (required): The search query keywords
# - `region` (optional): The search region (e.g., us-en, uk-en, ru-ru)
# - `max_results` (optional): The maximum number of results to return
#
# These tools enable me to:
# - Retrieve detailed product specifications for electronics
# - Check return policies for different product categories
# - Provide technical support for specific issues
# - Verify warranty status using serial numbers
# - Search the web for updated technical documentation and information
#
# Based on your context, I can particularly help you with:
# - **Headphones**: For your competitive FPS gaming needs with low latency audio
# - **Laptops**: For your programming work requirements
# - **MacBook Pro support**: For your video editing work and overheating issues
# - **Warranty check**: For your MacBook Pro (order #MB-78432)
#
# Would you like me to help you with any specific product information or support using these tools?
#
# I see the user is asking me to list all of my tools again. Let me provide a comprehensive list of all available tools with descriptions and parameters.
#
# ## Available Tools
#
# Here are all the tools I have access to:
#
# ### 1. **get_product_info**
# **Description**: Get detailed technical specifications and information for electronics products.
#
# **Parameters**:
# - `product_type` (required): Electronics product type (e.g., 'laptops', 'smartphones', 'headphones', 'monitors')
#
# ### 2. **get_return_policy**
# **Description**: Get return policy information for a specific product category.
#
# **Parameters**:
# - `product_category` (required): Electronics category (e.g., 'smartphones', 'laptops', 'accessories')
#
# ### 3. **get_technical_support**
# **Description**: Provide technical support for specific issues
#
# **Parameters**:
# - `issue_description` (required): Description of the technical issue
#
# ### 4. **LambdaUsingSDK___check_warranty_status**
# **Description**: Check the warranty status of a product using its serial number and optionally verify via email
#
# **Parameters**:
# - `serial_number` (required): Property serial_number
# - `customer_email` (optional): Property customer_email
#
# ### 5. **LambdaUsingSDK___web_search**
# **Description**: Search the web for updated information using DuckDuckGo
#
# **Parameters**:
# - `keywords` (required): The search query keywords
# - `region` (optional): The search region (e.g., us-en, uk-en, ru-ru)
# - `max_results` (optional): The maximum number of results to return
#
# These tools enable me to:
# - Retrieve detailed product specifications for electronics
# - Check return policies for different product categories
# - Provide technical support for specific issues
# - Verify warranty status using serial numbers
# - Search the web for updated technical documentation and information
#
# Based on your context, I can particularly help you with:
# - **Headphones**: For your competitive FPS gaming needs with low latency audio
# - **Laptops**: For your programming work requirements
# - **MacBook Pro support**: For your video editing work and overheating issues
# - **Warranty check**: For your MacBook Pro (order #MB-78432)
#
# Would you like me to help you with any specific product information or support using these tools?
#
# --------------------------------------------------
#
# Test Case 2: Search the web for heating issues with Samsung zfold 7
# --------------------------------------------------
#
# Tool #1: LambdaUsingSDK___web_search
# I apologize for the error in retrieving information about Samsung ZFold 7 heating issues. Let me try searching again with a slightly different approach to get you the information you need.
#
# Let me search for general overheating issues with Samsung foldables to provide you with helpful information:I apologize for the error in retrieving information about Samsung ZFold 7 heating issues. Let me try searching again with a slightly different approach to get you the information you need.
#
# Let me search for general overheating issues with Samsung foldables to provide you with helpful information:
#
# --------------------------------------------------
#
# Test Case 3: Search the internet for heating issues with iPhone 8
# --------------------------------------------------
#
# --------------------------------------------------
# \n✅ Policy testing completed!

# %% [markdown]
# ### Congratulations! 🎉
#
#
# You have successfully completed Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# What You Accomplished:
#
# ##### Tool Centralization & Reusability:
#
# - Migrated web search from local tool to centralized AgentCore Gateway
# - Integrated existing enterprise Lambda functions (warranty check, customer profile)
# - Created a shared tool infrastructure that multiple agent types can access
#
# ##### Enterprise-Grade Security:
#
# - Implemented JWT-based authentication with Cognito integration
# - Configured secure inbound authorization for gateway access
# - Established identity-based access control for tool usage
#
# ##### Scalable Architecture Foundation:
#
# - Built reusable tools that serve multiple use cases (customer support, sales, returns processing)
# - Eliminated code duplication across different agents
# - Created centralized management for tool updates and maintenance
#
# ##### Current Limitations (We'll fix these next!):
#
# - **Local Development Environment** - Still running on your laptop, not production-ready
# - **Limited Observability** - No comprehensive monitoring of agent behavior and performance
# - **Manual Scaling** - Cannot automatically handle increased load or multiple concurrent users
#
# ##### Next Up: Lab 4 - Deploying to Production with AgentCore Runtime
#
# In Lab 4, you'll transform your prototype into a production-ready system with:
#
# - AgentCore Runtime for scalable agent deployment
# - Comprehensive observability with metrics, logging, and tracing
# - Auto-scaling capabilities to handle real-world traffic
#
# ### Resources
# - [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html)
# - [Strands Agents Documentation](https://github.com/strands-agents/sdk-python)
# - [Official Customer Support Sample](https://github.com/awslabs/amazon-bedrock-agentcore-samples/tree/main/02-use-cases/customer-support-assistant)
